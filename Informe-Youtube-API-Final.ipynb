# %% [markdown]
# # API YouTube #
# <br>
#
#
#
#
#
# <div style="display: flex;">
#     <div style="flex: 1;margin-right: 90px;">
#         La API de YouTube es una interfaz de programación de aplicaciones proporcionada por YouTube que permite a los desarrolladores acceder y manipular datos relacionados con vídeos, canales, listas de reproducción, comentarios y más. A través de la API de YouTube, los desarrolladores pueden crear aplicaciones que interactúen con la plataforma de YouTube, como crear, subir y gestionar vídeos, obtener información sobre canales y listas de reproducción, realizar búsquedas de vídeos y comentarios, obtener estadísticas y mucho más.
#      </div>
#     <div style="flex: 1; text-align: right;">
#         <img src='https://camo.githubusercontent.com/3492e111812ac08200d4acd9a0dce36ff18e22be558865d26aae570f4348996c/68747470733a2f2f6a6f736570686d75636972616578636c7573697665732e636f6d2f77702d636f6e74656e742f75706c6f6164732f323031392f30382f596f75547562652d446174612d4150492d4f766572766965772e6a7067' width="2000" height="500" >
#     </div>
# </div>

# %% [markdown]
# <div style="display: flex;">
#     <div style="flex: 1;margin-right: 90px;">
#
# La API de YouTube es como un conjunto de herramientas que YouTube proporciona a los desarrolladores para que puedan crear aplicaciones que interactúen con YouTube. Estas aplicaciones pueden hacer cosas como subir y gestionar vídeos, buscar vídeos y comentarios, obtener información sobre canales y listas de reproducción, y ver estadísticas, entre otras cosas. Básicamente, la API de YouTube permite a los desarrolladores acceder y trabajar con datos de YouTube en sus propias aplicaciones.
#      </div>
#     <div style="flex: 1; text-align: right;">
#         <img src='https://techblog.sdstudio.top/wp-content/uploads/2020/05/search-youtube-videos.jpg' width="2000" height="500" >
#     </div>
# </div>

# %% [markdown]
# ## Justificación ##
# El uso del API de YouTube tiene varias ventajas sobre el web scraping:
#
# <font color="red">*Acceso estructurado a los datos:*</font> El API de YouTube proporciona una estructura bien definida para acceder a los datos de YouTube. Puedes realizar consultas específicas y recibir los resultados en un formato estructurado, como JSON, lo que facilita su manipulación y análisis.
#
# <font color="red">*Cumplimiento de los términos de servicio:*</font> Al utilizar el API de YouTube, estás siguiendo los términos de servicio establecidos por YouTube y Google. Esto garantiza que estás utilizando los datos de YouTube de acuerdo con las reglas y restricciones establecidas por la plataforma.
#
# <font color="red">*Actualizaciones y mantenimiento:*</font> El API de YouTube es administrado y actualizado por el equipo de desarrollo de YouTube. Esto significa que si hay cambios en la plataforma, es más probable que el API se actualice para reflejar esos cambios, lo que te permite mantener tu aplicación sincronizada con las últimas funcionalidades de YouTube.
#
# <font color="red">*Rendimiento y eficiencia:*</font> El API de YouTube está diseñado para manejar grandes volúmenes de solicitudes y ofrecer respuestas rápidas y eficientes. Esto garantiza un mejor rendimiento y evita la sobrecarga de los servidores de YouTube.

# %% [markdown]
# ## Objetivos ##
# 1. Familiarizarse con el API de YouTube, además de obtener su API Key.
# 2. Obtener data de las estadísticas de un video o grupo de videos a partir del título de un video.
# 3. A partir de la URL obtener los comentarios de videos, con la finalidad de obtener los comentarios con mayor número de likes, su nube de palabras y un análisis de sentimientos.
# 4. Visualización de vistas de un canal a traves del tiempo.

# %% [markdown]
# ## Limitaciones  ##
# Mostramos las limitaciones al usar el API de youtube, a traves de la siguiente tabla, obtenida del trabajo  ["Plataforma para   Análisis de Mercado a través de Datos de Redes Sociales"](http://rte.espol.edu.ec/index.php/tecnologica/article/view/839/535) en la que se puede apreciar, que la accesibilidad a los datos de youtube, mediante su API es 10 de 30 puntos posibles.

# %% [markdown]
# <img src='apiTabla.png' width="700" height="700" >
# <center>Tabla1: Cálculo del Score de la Calidad/Relevancia de las Fuentes de Información.</center>

# %% [markdown]
# A pesar de que el puntaje obtenido es poco alentador, es mayor que sus competidores. Además que en este trabajo se podrán apreciar que los datos obtenidos a partir de esta API, pueden considerarse de mucha relevancia.
# Adicionalmente a lo mostrado, y para entender porque se obtuvo ese puntaje, debemos considerar las siguiente limitaciones y políticas impuestas por Youtube:
#
# <font color="red">*Cuotas de uso:*</font> YouTube establece límites en la cantidad de solicitudes que se pueden realizar al API en un período de tiempo determinado. Estas cuotas pueden variar según el tipo de solicitud y el tipo de cuenta utilizada. Si se supera la cuota asignada, es posible que debas esperar hasta que se restablezca para realizar más solicitudes.
#
# <font color="red">*Restricciones de contenido:*</font> YouTube tiene políticas estrictas en cuanto a la obtención y el uso de datos de contenido. Algunos tipos de contenido pueden estar restringidos o no ser accesibles a través del API, como contenido protegido por derechos de autor o contenido que viole las políticas de YouTube. Además que no se tiene acceso a los videos privados.
#
# <font color="red">*Autenticación y autorización:*</font> Para acceder al API de YouTube, debes autenticarte y obtener las credenciales adecuadas. Esto implica seguir un proceso de autorización y asegurarte de cumplir con las políticas de uso de YouTube en cuanto a la privacidad y seguridad de los datos de los usuarios.
#
# <font color="red">*Cambios en el API:*</font> YouTube puede realizar cambios en su API, lo que puede implicar la adición, eliminación o modificación de funciones. Es importante mantenerse actualizado con las actualizaciones y cambios realizados por YouTube para garantizar la compatibilidad continua con tu aplicación o proyecto.

# %% [markdown]
# ## Pasos para obtener el APi Key de Youtube ##

# %% [markdown]
# A continuación se mostrarán los pasos para obtener el API Key de Youtube:
#
# ### 1. Primero debemos ingresar a la siguiente página ["cloud google"](https://cloud.google.com/?utm_source=google&utm_medium=cpc&utm_campaign=latam-PE-all-es-dr-BKWS-all-all-trial-e-dr-1605194-LUAC0010196&utm_content=text-ad-none-any-DEV_c-CRE_512364917036-ADGP_Hybrid%20%7C%20BKWS%20-%20EXA%20%7C%20Txt%20~%20GCP_General-KWID_43700062784667371-kwd-301173107424&utm_term=KW_google%20cloud-ST_Google%20Cloud&gclid=CjwKCAjws7WkBhBFEiwAIi1681FHUhtnumLa5grlN1RI9QNmEWWIV5blX1kw3PWLlhIwzxcjyZCBKhoCNYsQAvD_BwE&gclsrc=aw.ds&hl=es)
#
# <img src='t1.png' width="500" height="500" >
#
# Luego se debe loguear con cualquier cuenta de correo electrónico.

# %% [markdown]
# ### 2. Se debe generar un nuevo proyecto.
# <br>
#
# <img src='t2.png' width="500" height="500" >
# <br>
#
# ### 3. Se le asigna un nombre al proyecto, y se da crear.
# <br>
#
# ![Texto alternativo](t4.png)
# <br>
#
# ### 4. Se muestra que el proyecto a sido creado.
# ![Texto alternativo](t5.png)
# <br>
#
# ### 5. Le damos click a Biblioteca.
# <br>
#
# <img src='t6.png' width="500" height="500" >
# <br>
#
# ### 6. Se debe buscar youtube y darle click.
# <br>
#
# <img src='t7.png' width="500" height="500" >
# <br>
#
# ### 7. Se escoge YouTube Data API V3.
# <br>
#
# <img src='t8.png' width="500" height="500" >
# <br>
#
# ### 8. Se da habilitar.
# <br>
#
# <img src='t9.png' width="500" height="500" >
# <br>
#
# ### 9. YouTube Data API, es parte de nuestro proyecto.
# <br>
#
# ![Texto alternativo](t10.png)
# <br>
#
# ### 10. Ahora le damos click a crear credenciales.
# <br>
#
# ![Texto alternativo](t11.png)
# <br>
#
# ### 11. Le damos click a Datos públicos y le damos siguiente.
# <br>
#
# <img src='t12.png' width="500" height="500" >
# <br>
#
# ### 12. Se mostrará la clave API Key, luego le damos listo.
# <br>
#
# <img src='t14.png' width="500" height="500" >
# <br>
#
# ### 13. Finalmente, disponemos del proyecto, y la clave API Key respectiva de YouTube DATA API.
# <br>
#
# ![Texto alternativo](t15.png)

# %% [markdown]
# <img src='https://www.comolohago.cl/wp-content/uploads/2008/06/youtube.jpg' width="500" height="500" >

# %% [markdown]
# ## <span style="color:#827870">Bibliotecas importadas</span>

# %% [markdown]
# <div style="display: flex;">
#     <div style="flex: 1;margin-right: 90px;">
#         Las recomendaciones de videos son una herramienta clave en YouTube que permite a los usuarios descubrir nuevo   contenido, facilita la reproducción continua y contribuye al aumento del tiempo de reproducción en la plataforma.
#         Gracias a la Api de YouTube,se puede obtener una variedad de información relacionada con cada video recomendado. Algunos de los datos más comunes que se pueden obtener incluyen: titulo del video, descripción del video, ID, enlace, número de likes, número de comentarios, número de vistas, fecha de publiación, entre otros.
#      </div>
#     <div style="flex: 1; text-align: right;">
#         <img src='https://img.europapress.es/fotoweb/fotonoticia_20190724100046_1200.jpg' width="2000" height="500" >
#     </div>
# </div>

# %% [markdown]
# | **Bibliotecas**                 | **Usos**                                                |
# |:-------------------------------:|:------------------------------------------------------:|
# |        **googleapiclient.discovery**       | Construye la instancia del cliente de la API de Youtube |
# |        **googleapiclient.errors**         | Contiene excepciones relacionadas con la API de google |
# |        **urllib.parse**            | Ayuda en la manipulación y trabajo de URL               |
# |         **selenium import webdriver** | Su funcionalidad es automatizar un navegador web        |
# |         **time**                   | Relaciona con el tiempo.                               |
# |         **matplotlib.pyplot as plt** | Genera visualizaciones, como gráficos, diagramas y figuras. |
# |         **WordCloud** | Visualización de palabras frecuentes en texto.        |
# |         **NLTK**                   |  Biblioteca para procesamiento del lenguaje natural.                               |
# |         **Stopwords** |  Palabras comunes irrelevantes en análisis de texto. |
# |         **SentimentIntensityAnalyzer** |  Analizador de sentimientos basado en reglas |
# |         **YouTubeVideo** |  Mostrar videos de YouTube en Jupyter |

# %% [markdown]
# ## <span style="color:#000000">**Recomendaciones a partir del título de un video**</span>

# %% [markdown]
# ### <span style="color:#EE0000">1. Datos importantes de un video</span>

# %%
#https://www.youtube.com/watch?v=yKtBmciU3AM

import googleapiclient.discovery
import googleapiclient.errors
from selenium import webdriver
import time

video_url = input("Ingresar el enlace del video: ")
# Credenciales de autenticación de la API de YouTube
api_key = "AIzaSyBtlNY36JrBI1ItamxPI0jLNE9CCNKkysI"

# Crear una instancia del cliente de la API de YouTube
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

# Iniciar el controlador de Selenium
driver = webdriver.Chrome()

def obtener_datos_video(url):
    # Abrir la URL en el navegador
    driver.get(url)

    # Esperar a que la página cargue completamente
    time.sleep(3)

    # Obtener el video_id de la URL
    video_id = driver.current_url.split('=')[1]

    try:
        # Llamar a la API para obtener información del video
        response = youtube.videos().list(part='snippet,statistics', id=video_id).execute()

        # Procesar la respuesta y obtener los datos del video
        datos_video = response['items'][0]['snippet']
        estadisticas_video = response['items'][0]['statistics']
        

        # Imprimir los datos del video
        

        print("Título del video:", datos_video['title'])
        print("ID del video:", video_id)
        print("Descripción del video:", datos_video['description'])
        print("Fecha de publicación del video:", datos_video['publishedAt'])
        print("Número de vistas:", estadisticas_video['viewCount'])
        print("Número de likes:", estadisticas_video['likeCount'])
        print("Número de comentarios:", estadisticas_video['commentCount'])

    except googleapiclient.errors.HttpError as e:
        print("Error al obtener datos del video:", e)
    
    
    
# Ejemplo de uso: obtener datos de un video

obtener_datos_video(video_url)

# Cerrar el controlador de Selenium
driver.quit()
# Out:
# Ingresar el enlace del video: https://www.youtube.com/watch?v=yKtBmciU3AM
# Título del video: Harry Potter y las Reliquias de la Muerte: "Harry nos llevaba en el corazón a todos a nosotros".
# ID del video: yKtBmciU3AM
# Descripción del video: Warner Bros Pictures
# Dirigida por David Yates
#
#
#
# Envíame tus sugerencias en: harrypotterspainespana@gmail.com
# Fecha de publicación del video: 2018-01-20T18:26:37Z
# Número de vistas: 1437037
# Número de likes: 18182
# Número de comentarios: 1267

# %% [markdown]
# ### <span style="color:#EE0000">2. Recomendaciones y gráfico de barras.</span>

# %%
#https://www.youtube.com/watch?v=yKtBmciU3AM

import googleapiclient.discovery
import googleapiclient.errors
import urllib.parse
import matplotlib.pyplot as plt

enlace_video_principal = input("Ingresar el enlace del video: ")

# Clave de API de YouTube (reemplaza con tu propia clave)
api_key = "AIzaSyBtlNY36JrBI1ItamxPI0jLNE9CCNKkysI"

def obtener_videos_recomendados_por_enlace(enlace_video):
    try:
        # Obtener el ID del video principal a partir del enlace
        video_id = urllib.parse.urlparse(enlace_video).query.split('=')[1]

        # Crear una instancia del cliente de la API de YouTube
        youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

        # Llamar a la API de YouTube para obtener los videos recomendados
        response = youtube.search().list(part='snippet', relatedToVideoId=video_id, type='video', maxResults=10).execute()
        videos_recomendados = response['items']

        # Obtener los títulos y números de likes de los videos recomendados
        titulos = []
        likes = []
        
        # Abrir el archivo para escribir los resultados
        with open("videos_recomendados.txt", "w", encoding="utf-8") as file:
            # Escribir los detalles de los videos recomendados en el archivo
            file.write("Videos recomendados:\n")
            for video in videos_recomendados:
                # Obtener el ID del video recomendado
                video_id = video['id']['videoId']
                
         

                # Llamar a la API de YouTube para obtener estadísticas del video recomendado
                video_response = youtube.videos().list(part='snippet,statistics', id=video_id).execute()
                video_info = video_response['items'][0]

                # Obtener los detalles del video recomendado
                titulo = video_info['snippet']['title']
                descripcion = video_info['snippet']['description']
                like_count = int(video_info['statistics']['likeCount'])
                comentarios = video_info['statistics']['commentCount']
                enlace = f"https://www.youtube.com/watch?v={video_id}"
                
                # Escribir los detalles del video recomendado en el archivo
                file.write("Título: {}\n".format(titulo))
                file.write("Descripción: {}\n".format(descripcion))
                file.write("Número de likes: {}\n".format(like_count))
                file.write("Número de comentarios: {}\n".format(comentarios))
                file.write("Enlace: {}\n".format(enlace))
                file.write("\n")
                
                 # Imprimir los detalles del video recomendado
                print("Título:", titulo)
                #print("Descripción:", descripcion)
                print("Número de likes:", like_count)
                print("Número de comentarios:", comentarios)
                print("Enlace:", enlace)
                print()

                # Agregar el título y número de likes a las listas correspondientes
                if like_count > 7000:  # Más de 10,000 likes
                    titulos.append(titulo)
                    likes.append(like_count)


        # Personalizar colores para las barras
        yt = ['#282828','#606060','#E0E0E0','#FF0000','#CD0000']
        # Crear el gráfico de barras con colores personalizados
        plt.bar(titulos, likes, color=yt)
        plt.xlabel('Títulos de videos')
        plt.ylabel('Número de likes')
        plt.title('Videos recomendados por título y número de likes')
        plt.xticks(rotation=90)
        plt.tight_layout()
        plt.show()  
        
    except googleapiclient.errors.HttpError as e:
        print("Error HTTP al llamar a la API de YouTube:", e)
    except googleapiclient.errors.Error as e:
        print("Error al llamar a la API de YouTube:", e)

# Ejemplo de uso: obtener videos recomendados a partir del enlace del video principal
obtener_videos_recomendados_por_enlace(enlace_video_principal)
# Out:
# Ingresar el enlace del video: https://www.youtube.com/watch?v=yKtBmciU3AM
# Título: Harry Potter y el misterio del príncipe. Muerte de Dumbledore parte 1 - HD
# Número de likes: 6760
# Número de comentarios: 425
# Enlace: https://www.youtube.com/watch?v=oW-M5PRuUq8
#
# Título: HP7 HARRY VS VOLDEMORT HD
# Número de likes: 19776
# Número de comentarios: 1423
# Enlace: https://www.youtube.com/watch?v=6QtkFmruMcQ
#
# Título: Harry Potter y el Misterio del Príncipe: Juramento Inquebrantable
# Número de likes: 1854
# Número de comentarios: 104
# Enlace: https://www.youtube.com/watch?v=XGQqYNwihoM
#
# Título: Ultimos minutos de vida de Dobby (Harry Potter y las reliquias de la muerte parte 1) [HD]
# Número de likes: 5473
# Número de comentarios: 744
# Enlace: https://www.youtube.com/watch?v=ZialmTM5cxo
#
# Título: Tom Jedusor is back !
# Número de likes: 393
# Número de comentarios: 0
# Enlace: https://www.youtube.com/watch?v=Qc6RsDt21S4
#
# ...

# %% [markdown]
# ## <span style="color:#000000">Comentarios a partir del URL de un video</span>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://miracomosehace.com/wp-content/uploads/mch/comentarios-youtube-logo--_16732.jpg" alt="Texto alternativo" width=450>
# </div>

# %% [markdown]
# ### <span style="color:#EE0000">1. Comentarios con mayor número de likes </span>

# %%
import googleapiclient.discovery
import googleapiclient.errors
import urllib.parse

# Clave de API de YouTube (reemplaza con tu propia clave)
api_key = "AIzaSyBtlNY36JrBI1ItamxPI0jLNE9CCNKkysI"

def obtener_comentarios_mas_populares(enlace_video, cantidad):
    
    try:
        # Obtener el ID del video a partir del enlace
        video_id = urllib.parse.urlparse(enlace_video).path.split('/')[1]

        # Crear una instancia del cliente de la API de YouTube
        youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

        # Llamar a la API de YouTube para obtener los comentarios del video
        response = youtube.commentThreads().list(part='snippet', videoId=video_id, order='relevance', textFormat='plainText').execute()
        comentarios = response['items']

        # Ordenar los comentarios por número de likes de mayor a menor
        comentarios_ordenados = sorted(comentarios, key=lambda x: int(x['snippet']['topLevelComment']['snippet']['likeCount']), reverse=True)

        # Obtener los comentarios más populares
        comentarios_populares = comentarios_ordenados[:cantidad]

        # Imprimir los comentarios más populares
        print(f"Los {cantidad} comentarios con más likes:")
        for i, comentario in enumerate(comentarios_populares, start=1):
            likes = comentario['snippet']['topLevelComment']['snippet']['likeCount']
            texto_comentario = comentario['snippet']['topLevelComment']['snippet']['textDisplay']
            #print(f"Comentario {i}:")
            print(f"Likes: {likes}")
            print(f"Comentario: {texto_comentario}")
            print()                                                              

    except googleapiclient.errors.HttpError as e:
        print("Error HTTP al llamar a la API de YouTube:", e)
    except googleapiclient.errors.Error as e:
        print("Error al llamar a la API de YouTube:", e)

# Ejemplo de uso: obtener los 5 comentarios con más likes a partir del enlace de un video
enlace_video = "https://youtu.be/yKtBmciU3AM"  # Reemplaza con el enlace del video deseado
cantidad_comentarios = 5  # Cantidad de comentarios a obtener
comentarios_mas_populares=obtener_comentarios_mas_populares(enlace_video, cantidad_comentarios)
# Out:
# Los 5 comentarios con más likes:
# Likes: 1544
# Comentario: Harry nos llevaba en el el corazón, a todos nosotros~Neville Longbottom. Es una de las frases más bonitas de toda la saga. ❤😢
#
# Likes: 196
# Comentario: la cara de draco me da mucha ternura se nota que el quiere quedarse con ellos pero solo se mueve para que nada malo le pase a su mama
#
# Likes: 137
# Comentario: A Voldy se le cayeron hasta los calzones cuando vio que Harry no estaba "muerto" JAKSJAK su cara de impresión lo es todo.
#
# Likes: 61
# Comentario: Jajajaj nunca superaré la cara de Voldemort cuando ve a Harry
#
# Likes: 45
# Comentario: Cuando descubren que Harry no está muerto, George se gira para decírselo a Fred, pero se encuentra con que no hay nadie a quien contárselo.

# %% [markdown]
# ### <span style="color:#EE0000">2. Nube de palabras</span>

# %%
import googleapiclient.discovery
import googleapiclient.errors
import urllib.parse
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Clave de API de YouTube (reemplaza con tu propia clave)
api_key = "AIzaSyBtlNY36JrBI1ItamxPI0jLNE9CCNKkysI"

def obtener_comentarios_mas_populares(enlace_video, cantidad):
    try:
        # Obtener el ID del video a partir del enlace
        video_id = urllib.parse.urlparse(enlace_video).path.split('/')[1]

        # Crear una instancia del cliente de la API de YouTube
        youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

        # Llamar a la API de YouTube para obtener los comentarios del video
        response = youtube.commentThreads().list(part='snippet', videoId=video_id, order='relevance', textFormat='plainText').execute()
        comentarios = response['items']

        # Ordenar los comentarios por número de likes de mayor a menor
        comentarios_ordenados = sorted(comentarios, key=lambda x: int(x['snippet']['topLevelComment']['snippet']['likeCount']), reverse=True)

        # Obtener los comentarios más populares
        comentarios_populares = comentarios_ordenados[:cantidad]

        # Obtener las palabras vacías en español
        stopwords_es = set(stopwords.words('spanish'))

        # Generar el texto para la nube de palabras
        texto_comentarios = ''
        for comentario in comentarios_populares:
            texto = comentario['snippet']['topLevelComment']['snippet']['textDisplay']
            texto_comentarios += texto + ' '

        # Generar la nube de palabras
        wordcloud = WordCloud(stopwords=stopwords_es,width=800, height=400, background_color='white',colormap='autumn').generate(texto_comentarios)
        
        # Mostrar la nube de palabras
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.show()

    except googleapiclient.errors.HttpError as e:
        print("Error HTTP al llamar a la API de YouTube:", e)
    except googleapiclient.errors.Error as e:
        print("Error al llamar a la API de YouTube:", e)

# Ejemplo de uso: obtener los 5 comentarios con más likes a partir del enlace de un video
enlace_video = "https://youtu.be/yKtBmciU3AM"  # Reemplaza con el enlace del video deseado
cantidad_comentarios = 5  # Cantidad de comentarios a obtener
obtener_comentarios_mas_populares(enlace_video, cantidad_comentarios)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\20211\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %% [markdown]
# ### <span style="color:#ED0000">3. Análisis de sentimientos </span>

# %% [markdown]
# El video elegido para el análisis de sentimientos es **CASO UTOPIA - REPORTAJE PRIMER IMPACTO**.

# %%
#Este código permite visualizar el video en jupyter notebook
from IPython.display import YouTubeVideo

# crea una instancia de YouTubeVideo
video = YouTubeVideo('1ODi5NOrFK4')

# muestra el video en una celda de Markdown
display(video)

# %%
import googleapiclient.discovery
import googleapiclient.errors
import urllib.parse
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer

# Clave de API de YouTube (reemplaza con tu propia clave)
api_key = "AIzaSyBtlNY36JrBI1ItamxPI0jLNE9CCNKkysI"

def analizar_sentimientos(enlace_video):
    try:
        # Obtener el ID del video a partir del enlace
        video_id = urllib.parse.urlparse(enlace_video).path.split('/')[1]

        # Crear una instancia del cliente de la API de YouTube
        youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=api_key)

        # Llamar a la API de YouTube para obtener los comentarios del video
        response = youtube.commentThreads().list(part='snippet', videoId=video_id, order='relevance', textFormat='plainText').execute()
        comentarios = response['items']

        # Inicializar el analizador de sentimientos VADER
        sia = SentimentIntensityAnalyzer()

        # Analizar los sentimientos de cada comentario
        for i, comentario in enumerate(comentarios, start=1):
            texto_comentario = comentario['snippet']['topLevelComment']['snippet']['textDisplay']

            # Obtener el puntaje de sentimiento del comentario
            sentimiento = sia.polarity_scores(texto_comentario)

            # Imprimir el resultado
            print(f"Comentario {i}:")
            print(f"Texto: {texto_comentario}")
            print(f"Sentimiento: {sentimiento}")
            print()

    except googleapiclient.errors.HttpError as e:
        print("Error HTTP al llamar a la API de YouTube:", e)
    except googleapiclient.errors.Error as e:
        print("Error al llamar a la API de YouTube:", e)

# Ejemplo de uso: analizar los sentimientos de los comentarios de un video de YouTube
enlace_video = "https://youtu.be/1ODi5NOrFK4"  # Reemplaza VIDEO_ID con el ID del video deseado
analizar_sentimientos(enlace_video)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\20211\AppData\Roaming\nltk_data...
# Comentario 1:
# Texto: Álvaro, un ángel que salvó 13 personas, sacrificándose por ellos. Descansa en paz.
# Sentimiento: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Comentario 2:
# Texto: Vi la película me Dio mucha pena, los padres hicieron lo que pudieron en torno a  la justicia vendida del Perú.
# Sentimiento: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Comentario 3:
# Texto: Vi la película y no pude evitar las lágrimas.
# Justicia para los 29 chicos
# Sentimiento: {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.296}
#
# Comentario 4:
# Texto: Indignante como la corrupción tiene tanto poder , me da mucha tristeza por esos 29 jóvenes y las familias afectadas , pero tarde o temprano se hará justicia porque todo se paga en esta vida
# Sentimiento: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Comentario 5:
# ...

# %% [markdown]
# ## Visualizacion de las vistas de un canal a lo largo del tiempo

# %% [markdown]
# La visualizacion de las vistas de un canal puede llegar a ser una herramienta fundamental para los desarrolladores de contenido, ya que esta les facilitara ver e identificar tendencias de contenido, evaluar la popularidad de un cierto contenido, ademas de servir como indicador del crecimiento de un canal.
#
# <img src='conversion.jpg' width="800" height="800" >

# %% [markdown]
# ### Paquetes utilizados

# %% [markdown]
# | **Paquetes**                 | **Usos**                                                |
# |:-------------------------------:|:------------------------------------------------------:|
# |        **googleapiclient.discovery**       | Construye la instancia del cliente de la API de Youtube |
# |        **Pandas**                          | Ayudara al analisis de datos |
# |        **Seaborn**                          | Proporsiona herramientos para creacion de graficos |
# |        **matplotlib.pyplot**                          | Proporsiona la interfaz para creacion de graficos |

# %%
from googleapiclient.discovery import build
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### <span style="color:#EE0000">1. Datos importantes de un canal</span>

# %%
#Credenciales del API de youtube
key = 'AIzaSyBvHJk8VmlfWnIpwqMcUWuCFQnGsYpigic'

# Crear una instancia del cliente de la API de YouTube
youtube = build('youtube','v3',developerKey = key)

#definimos una funcion para extraer las estadisticas de un canal
def estadisticas_canal(instancia, canal):
    #Creamos una lista en blanco donde se guardara la informacion que se extrae de los canales
    canales = []
    #Creamos una solicitud para pedir informacion relacionada con el endpoint channels que referencia a los canales
    solicitud = instancia.channels().list(
    part = 'snippet,contentDetails,statistics',
    id = canal)
    #Guardamos la respuesta de la solicitud realizada
    respuesta = solicitud.execute()
    #Establecemos un bucle desde 0 hasta el numero de 'items' de la respuesta
    for i in range(len(respuesta['items'])):
        #Guardamos los datos como un diccionario
        datos = dict(nombre_canal = respuesta['items'][i]['snippet']['title'],
                 suscriptores = int(respuesta['items'][i]['statistics']['subscriberCount']),
                 vistas = int(respuesta['items'][i]['statistics']['viewCount']),
                 numero_videos = int(respuesta['items'][i]['statistics']['videoCount']),
                 id_playlist = respuesta['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        canales.append(datos)
    return canales

# %% [markdown]
# ### <span style="color:#EE0000">2. Extraccion de identificadores de videos</span>

# %%
#Definimos una funcion para extraer y guardar en una lista todos los id de los videos de playlist
def identificadores(instancia, id_playlist):
    #Creamos una solicitud para extraer informacion relacionada a las playlist del canal
    solicitud = instancia.playlistItems().list(
                part='contentDetails',
                playlistId=id_playlist,
                maxResults=50)
    #Guardamos la solicitud realizada
    respuesta = solicitud.execute()
    #Creamos una lista para guardar la informacion relacionada con los videos
    id_videos = []
    
    #Establecemos una iteracion desde 0 hasta el numero de 'items' de la respuesta
    for i in range(len(respuesta['items'])):
        id_videos.append(respuesta['items'][i]['contentDetails']['videoId'])
    
    #Creamos un objeto 'pasar_pagina' y 'mas_paginas' ayudaran a controlar la paginacion de videos
    pasar_pagina = respuesta['nextPageToken']
    mas_paginas = True
    
    while mas_paginas:
        if pasar_pagina is None:
            mas_paginas = False
        else:
            solicitud = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId=id_playlist,
                        maxResults=50,
                        pageToken=pasar_pagina)
            respuesta = solicitud.execute()
            for i in range(len(respuesta['items'])):
                id_videos.append(respuesta['items'][i]['contentDetails']['videoId'])
                
            pasar_pagina = respuesta.get('nextPageToken')
            
    return id_videos

# %% [markdown]
# ### <span style="color:#EE0000">3. Extracion de estadisticas de videos</span>

# %%
#Definimos una funcion para extraer las estadisticas de las videos
def estadisticas_videos(instancia, identificadores):
    #Se crea una lista vacia donde se guardara las estadisticas de todos los videos
    estadisticas_videos = []
    for i in range(0,len(identificadores),50):
        solicitud = youtube.videos().list(
        part = 'snippet, statistics',
        id = ','.join(identificadores[i:i+50]))
        respuesta = solicitud.execute()
        for j in respuesta['items']:
            #Se crea un diccionario con las estadisticas de cada video y luego se guarda en la lista vacia
            estadisticas = dict(Titulo = j['snippet']['title'],
                               fecha_publicacion = j['snippet']['publishedAt'],
                               Vistas = int(j['statistics'].get('viewCount',0)),
                               Likes = int(j['statistics'].get('likeCount',0)),
                               Dislikes = j['statistics'].get('dislikeCount',0),
                               Comentarios = int(j['statistics'].get('commentCount',0)))
            estadisticas_videos.append(estadisticas)
    return estadisticas_videos

# %% [markdown]
# ### Ejemplo:

# %% [markdown]
# Para este ejemplo usaremos una lista con 5 identificadores de canales pre-elegidos.
# Advertencia: Debido a actualizaciones de Youtube, los identificadores no salen de manera natural como antes, por lo cual utilizamos un extractor de identificadores  (https://commentpicker.com/youtube-channel-id.php).

# %%
canales_ejemplo = ['UCX6OQ3DkcsbYNE6H8uQQuVA',
         'UCok4dp9tEPNjCyq93xfB0hw',
         'UCK1W7jhV8g0JuAJbaZYyehA',
         'UCJxv80y78XTCUqfiplmDyRw',
         'UCV4xOVpbcV8SdueDCOxLXtQ']

# %%
ejemplo_stvideo = estadisticas_canal(youtube,canales_ejemplo)
ejemplo_stvideo
# Out:
# [{'nombre_canal': 'Dylantero Sin Imaginación',
#   'suscriptores': 2420000,
#   'vistas': 514166808,
#   'numero_videos': 510,
#   'id_playlist': 'UUK1W7jhV8g0JuAJbaZYyehA'},
#  {'nombre_canal': 'Tri-line',
#   'suscriptores': 6750000,
#   'vistas': 1793514885,
#   'numero_videos': 552,
#   'id_playlist': 'UUJxv80y78XTCUqfiplmDyRw'},
#  {'nombre_canal': 'PUVLO',
#   'suscriptores': 677000,
#   'vistas': 100164462,
#   'numero_videos': 154,
#   'id_playlist': 'UUok4dp9tEPNjCyq93xfB0hw'},
#  {'nombre_canal': 'MrBeast',
#   'suscriptores': 161000000,
#   'vistas': 27225060263,
#   'numero_videos': 739,
#   'id_playlist': 'UUX6OQ3DkcsbYNE6H8uQQuVA'},
#  {'nombre_canal': 'Fernanfloo',
#   'suscriptores': 46000000,
#   'vistas': 10294687313,
#   'numero_videos': 543,
#   'id_playlist': 'UUV4xOVpbcV8SdueDCOxLXtQ'}]

# %% [markdown]
# Se genero un objeto llamado 'ejemplo_stvideo' el cual es un diccionario, para poder trabajarlo mejor lo convertiremos en un data frame.

# %%
ejemplo_stvideo = pd.DataFrame(ejemplo_stvideo)
ejemplo_stvideo
# Out:
#                 nombre_canal  suscriptores       vistas  numero_videos  \
# 0  Dylantero Sin Imaginación       2420000    514166808            510
# 1                   Tri-line       6750000   1793514885            552
# 2                      PUVLO        677000    100164462            154
# 3                    MrBeast     161000000  27225060263            739
# 4                 Fernanfloo      46000000  10294687313            543
#
#                 id_playlist
# 0  UUK1W7jhV8g0JuAJbaZYyehA
# 1  UUJxv80y78XTCUqfiplmDyRw
# 2  UUok4dp9tEPNjCyq93xfB0hw
# 3  UUX6OQ3DkcsbYNE6H8uQQuVA
# 4  UUV4xOVpbcV8SdueDCOxLXtQ

# %% [markdown]
# Ahora elegimos el canal 'PUVLO' para extraer su 'id_playlist', y asi poder obtener las estadisticas de todos sus videos.

# %%
PUVLO_ch = ejemplo_stvideo.loc[ejemplo_stvideo['nombre_canal']=='PUVLO','id_playlist'].values[0]
PUVLO_ch
# Out:
# 'UUok4dp9tEPNjCyq93xfB0hw'

# %% [markdown]
# Una vez tengamos el identificador de la playlist podremos obtener cada uno de los identificadores de los videos del canal y guardarlos en una lista.

# %%
id_videos = identificadores(youtube,PUVLO_ch)

# %%
videos_PUVLO = estadisticas_videos(youtube,id_videos)
videos_PUVLO = pd.DataFrame(videos_PUVLO)
videos_PUVLO
# Out:
#                                              Titulo     fecha_publicacion  \
# 0                       HICIMOS MAGIA NEGRA!!! 😈😱💀✨  2023-06-13T01:03:28Z
# 1     HICIMOS LA MARUCHAN MAS GRANDE DE MÉXICO! 😱🤑😡  2023-05-05T03:10:32Z
# 2               PASAMOS 24 HORAS EN LA CARCEL! 😰😭👿💀  2023-04-12T04:42:38Z
# 3                     LE HICIMOS UN BABYSHOWER! 🤑😱😈  2023-03-29T03:25:12Z
# 4                               FUIMOS A AFRICA 🥵🐘🌍  2023-03-16T02:52:52Z
# ..                                              ...                   ...
# 150        Mi Hijo Otaku /Ft. MAAU | Cortometraje |  2016-11-12T02:24:08Z
# 151                     Emisión en directo de PUVLO  2016-09-14T05:05:02Z
# 152     CASOS REALES DE FANTASMAS CON EL URIEL MAAU  2016-06-19T22:15:22Z
# 153  VLOG!!! | ElUriel y MAAU | Juntos Para Siempre  2016-06-14T20:20:49Z
# 154                              EL GATO CON CANCER  2016-05-17T20:16:50Z
#
#      Vistas  Likes  Dislikes  Comentarios
# ...

# %%
videos_PUVLO['Fecha'] = pd.to_datetime(videos_PUVLO['fecha_publicacion']).dt.date
videos_PUVLO
# Out:
#                                              Titulo     fecha_publicacion  \
# 0                       HICIMOS MAGIA NEGRA!!! 😈😱💀✨  2023-06-13T01:03:28Z
# 1     HICIMOS LA MARUCHAN MAS GRANDE DE MÉXICO! 😱🤑😡  2023-05-05T03:10:32Z
# 2               PASAMOS 24 HORAS EN LA CARCEL! 😰😭👿💀  2023-04-12T04:42:38Z
# 3                     LE HICIMOS UN BABYSHOWER! 🤑😱😈  2023-03-29T03:25:12Z
# 4                               FUIMOS A AFRICA 🥵🐘🌍  2023-03-16T02:52:52Z
# ..                                              ...                   ...
# 150        Mi Hijo Otaku /Ft. MAAU | Cortometraje |  2016-11-12T02:24:08Z
# 151                     Emisión en directo de PUVLO  2016-09-14T05:05:02Z
# 152     CASOS REALES DE FANTASMAS CON EL URIEL MAAU  2016-06-19T22:15:22Z
# 153  VLOG!!! | ElUriel y MAAU | Juntos Para Siempre  2016-06-14T20:20:49Z
# 154                              EL GATO CON CANCER  2016-05-17T20:16:50Z
#
#      Vistas  Likes  Dislikes  Comentarios       Fecha
# ...

# %%
sns.set(style='darkgrid')
sns.lineplot(data=videos_PUVLO, x='fecha_publicacion', y='Vistas')
plt.xlabel('Fechas de publicacion (2016-2023)')
plt.ylabel('Vistas en millones ')
plt.xticks([])
plt.show()
